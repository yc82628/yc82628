# %% [markdown]
# <a href="https://colab.research.google.com/github/yc82628/yc82628/blob/main/Week_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Week 4
import matplotlib.pyplot as plt
import numpy as np ## we almost always use matplotlib with nmupy

#define data
x = np.array([8, 2, 11, 6, 5, 4, 12, 9, 6, 1])
y = np.array([3, 10, 3, 6, 8, 12, 1, 4, 9, 14])

# find line of best fit
a, b = np.polyfit(x,y, 1)

# add points to plot
plt.scatter(x,y, color = 'red')

# add line of best fit to plot
plt.plot(x, a*x+b, color = 'blue', linestyle = '--', linewidth= 2)

# add fitted regression equation to plot
plt.text(1, 17,'y = ' + '{:.2f}'.format(b) + '{:.2f}'.format(a) + 'x', size = 14)
plt.show()
